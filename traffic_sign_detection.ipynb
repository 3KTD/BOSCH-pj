# %% [markdown]
# <a href="https://colab.research.google.com/github/3KTD/BOSCH-pj/blob/main/traffic_sign_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls drive/MyDrive/trafficsigndetection
# Out:
# dataset.zip

# %%
# !unzip drive/MyDrive/trafficsigndetection/dataset.zip
# Out:
# Archive:  drive/MyDrive/trafficsigndetection/dataset.zip
#    creating: dataset/
#    creating: dataset/test/
#    creating: dataset/test/images/
#   inflating: dataset/test/images/103_jpg.rf.6768a168ceac4d8eb7bb1d9f835cc600.jpg
#   inflating: dataset/test/images/105_jpg.rf.f0ec7616433ea1856b271d7e3098f3e3.jpg
#   inflating: dataset/test/images/10_jpg.rf.057f2f8124d26c73b6deb53b73e7a360.jpg
#   inflating: dataset/test/images/10_jpg.rf.811fd362c5ce756458bc07ec6b10f284.jpg
#   inflating: dataset/test/images/10_jpg.rf.9ea33e2ad50272a57922993d154a7f0c.jpg
#   inflating: dataset/test/images/10_jpg.rf.e16e6ebdb023009858815b88aae6334f.jpg
#   inflating: dataset/test/images/10_jpg.rf.e7b5edad9686257bf04df6d20885cba6.jpg
#   inflating: dataset/test/images/118_jpg.rf.ea2c2ec0475f9118fb66b65349d76aac.jpg
#   inflating: dataset/test/images/11_jpg.rf.20e42863c1698a708cff8faf8a138bb8.jpg
#   inflating: dataset/test/images/12_jpg.rf.a8534517e3c7e1847fd9a21df4448342.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.0/646.0 kB 8.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os

# load a model
model = YOLO("yolov8s.pt") #build a new model from scratch
# use the model
results = model.train(data="/content/data_colab.yaml", epochs=10, batch=16) #train the model
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 310MB/s]
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import numpy as np
import cv2
from ultralytics import YOLO
import random

model = YOLO('/content/runs/detect/train/weights/best.pt')
results = model('/content/1.jpg')
# Out:
# image 1/1 /content/1.jpg: 480x640 1 CamXeTai, 96.3ms
# Speed: 5.4ms preprocess, 96.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
