# %% [markdown]
# <a href="https://colab.research.google.com/github/3KTD/BOSCH-pj/blob/main/Line_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
# load image
img = cv2.imread('/content/lane.jpg')

# %%
# import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
# load image
img = cv2.imread('/content/lane.jpg')
# show image
plt.imshow(img)
plt.show()

# %%
# import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
# load image
img = cv2.imread('/content/lane.jpg')
# show image
img =cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
# import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
# load image
img = cv2.imread('/content/lane.jpg')
# convert gray
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# show image
plt.imshow(gray, cmap = 'gray')
plt.show()

# %%
# create a copy image
img_copy = img.copy()
# convert to gray
gray = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)
# noise filter
gauss_gray = cv2.GaussianBlur(gray, (5,5), 0)
# canny filter
# canny = cv2.Canny(gauss_gray, 60, 150)
plt.imshow(gauss_gray, cmap = 'gray')
plt.show()

# %%
# create a copy image
img_copy = img.copy()
# convert to gray
gray = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)
# noise filter
gauss_gray = cv2.GaussianBlur(gray, (5,5), 0)
# canny filter
canny = cv2.Canny(gauss_gray, 60, 150)
plt.imshow(canny, cmap = 'gray')
plt.show()

# %%
def crop_roi(image):
  polygons = np.array([[(200,704),(1100,704), (550,250)]])
  mask = np.zeros_like(image)
  cv2.fillPoly(mask, polygons, 255)
  masked_image = cv2.bitwise_and(image,mask)
  return masked_image

# %%
mm = crop_roi(img)
mm = cv2.cvtColor(mm, cv2.COLOR_BGR2RGB)
plt.imshow(mm)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mm = crop_roi(canny)
mm = cv2.cvtColor(mm, cv2.COLOR_BGR2RGB)
plt.imshow(mm)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# find coordinate from slope, intercept
def find_coordinate(img, lind_param):
  slope, intercept = line_param
  y1 = img.shape[0]
  y2 = int(y1*(2.5/5))
  x1 = int(y1 - (intercept/slope))
  x1 = int(y2 - (intercept/slope))
  return [x1,y1,x2,y2]
# find a line from similar lines
def merger_lines(img, lines):
  left_lines = []
  right_lines = []

  for line in lines:
    x1,y1,x2,

# %%
# crop img
crop_img = crop_roi(canny)
# hough transfrom #(33,1,4)
mask = np.zeros_like(img)
lines = cv2.HoughLinesP(crop_img, 2, np.pi/180, 100, minLineLength = 40, maxLineGap = 5)
# display line
# mask = np.zeros_like(img)
try: some_lines = merge_lines(img, lines)
